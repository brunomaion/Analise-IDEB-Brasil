# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import sys
import joblib

df = pd.read_excel("RELATORIO_DTB_BRASIL_MUNICIPIO.xls", skiprows=6)
total_linhas = len(df)

display(df)
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# *** No CODEPAGE record, no encoding_override: will use 'iso-8859-1'
#       UF           Nome_UF  Região Geográfica Intermediária  \
# 0     11          Rondônia                             1102
# 1     11          Rondônia                             1102
# 2     11          Rondônia                             1101
# 3     11          Rondônia                             1102
# 4     11          Rondônia                             1101
# ...   ..               ...                              ...
# 5565  52             Goiás                             5201
# 5566  52             Goiás                             5202
# 5567  52             Goiás                             5206
# 5568  52             Goiás                             5205
# 5569  53  Distrito Federal                             5301
#
#      Nome Região Geográfica Intermediária  Região Geográfica Imediata  \
# ...

# %% [markdown]
# # Mesorregião Geográfica

# %%
# PARANA = 41

dfPR = df[df['UF'] == 41]
display(dfPR)

dfMesoNoroesteParanaense = dfPR[dfPR['Mesorregião Geográfica'] == 1]
dfMesoCentroOcidentalParanaense = dfPR[dfPR['Mesorregião Geográfica'] == 2]
dfMesoNorteCentralParanaense = dfPR[dfPR['Mesorregião Geográfica'] == 3]
dfMesoNortePioneiroParanaense = dfPR[dfPR['Mesorregião Geográfica'] == 4]
dfMesoCentroOrientalParanaense = dfPR[dfPR['Mesorregião Geográfica'] == 5]
dfMesoOesteParanaense = dfPR[dfPR['Mesorregião Geográfica'] == 6]
dfMesoSudoesteParanaense = dfPR[dfPR['Mesorregião Geográfica'] == 7]
dfMesoCentroSulParanaense = dfPR[dfPR['Mesorregião Geográfica'] == 8]
dfMesoSudesteParanaense = dfPR[dfPR['Mesorregião Geográfica'] == 9]
dfMesoMetropolitana = dfPR[dfPR['Mesorregião Geográfica'] == 10]


display(dfPR['Mesorregião Geográfica'].value_counts())
display(dfMesoOesteParanaense)
# Out:
#       UF Nome_UF  Região Geográfica Intermediária  \
# 3912  41  Paraná                             4105
# 3913  41  Paraná                             4101
# 3914  41  Paraná                             4101
# 3915  41  Paraná                             4101
# 3916  41  Paraná                             4104
# ...   ..     ...                              ...
# 4306  41  Paraná                             4103
# 4307  41  Paraná                             4103
# 4308  41  Paraná                             4103
# 4309  41  Paraná                             4105
# 4310  41  Paraná                             4104
#
#      Nome Região Geográfica Intermediária  Região Geográfica Imediata  \
# 3912                             Londrina                      410022
# 3913                             Curitiba                      410001
# 3914                             Curitiba                      410001
# 3915                             Curitiba                      410001
# ...

# %%
dfMesoNoroesteParanaense = dfPR[dfPR['Mesorregião Geográfica'] == 1]
dfMesoCentroOcidentalParanaense = dfPR[dfPR['Mesorregião Geográfica'] == 2]
dfMesoNorteCentralParanaense = dfPR[dfPR['Mesorregião Geográfica'] == 3]
dfMesoNortePioneiroParanaense = dfPR[dfPR['Mesorregião Geográfica'] == 4]
dfMesoCentroOrientalParanaense = dfPR[dfPR['Mesorregião Geográfica'] == 5]
dfMesoOesteParanaense = dfPR[dfPR['Mesorregião Geográfica'] == 6]
dfMesoSudoesteParanaense = dfPR[dfPR['Mesorregião Geográfica'] == 7]
dfMesoCentroSulParanaense = dfPR[dfPR['Mesorregião Geográfica'] == 8]
dfMesoSudesteParanaense = dfPR[dfPR['Mesorregião Geográfica'] == 9]
dfMesoMetropolitana = dfPR[dfPR['Mesorregião Geográfica'] == 10]


municipiosNoroesteParanaense = dfMesoNoroesteParanaense['Nome_Município']
municipiosCentroOcidentalParanaense = dfMesoCentroOcidentalParanaense['Nome_Município']
municipiosNorteCentralParanaense = dfMesoNorteCentralParanaense['Nome_Município']
municipiosNortePioneiroParanaense = dfMesoNortePioneiroParanaense['Nome_Município']
municipiosCentroOrientalParanaensee = dfMesoCentroOrientalParanaense['Nome_Município']
municipiosOesteParanaense = dfMesoOesteParanaense['Nome_Município']
municipiosSudoesteParanaense = dfMesoSudoesteParanaense['Nome_Município']
municipiosCentroSulParanaense = dfMesoCentroSulParanaense['Nome_Município']
municipiosSudesteParanaense = dfMesoSudesteParanaense['Nome_Município']
municipiosMetropolitanae = dfMesoMetropolitana['Nome_Município']

joblib.dump(municipiosNoroesteParanaense, 'municipiosNoroesteParanaense.pkl')
joblib.dump(municipiosCentroOcidentalParanaense, 'municipiosCentroOcidentalParanaense.pkl')
joblib.dump(municipiosNorteCentralParanaense, 'municipiosNorteCentralParanaense.pkl')
joblib.dump(municipiosNortePioneiroParanaense, 'municipiosNortePioneiroParanaense.pkl')
joblib.dump(municipiosCentroOrientalParanaensee, 'municipiosCentroOrientalParanaensee.pkl')
joblib.dump(municipiosOesteParanaense, 'municipiosOesteParanaense.pkl')
joblib.dump(municipiosSudoesteParanaense, 'municipiosSudoesteParanaense.pkl')
joblib.dump(municipiosCentroSulParanaense, 'municipiosCentroSulParanaense.pkl')
joblib.dump(municipiosSudesteParanaense, 'municipiosSudesteParanaense.pkl')
joblib.dump(municipiosMetropolitanae, 'municipiosMetropolitanae.pkl')



print(var_municipiosOeste)
print(len(var_municipiosOeste))
# Out:
# 3924                        Anahy
# 3937          Assis Chateaubriand
# 3951       Boa Vista da Aparecida
# 3957                     Braganey
# 3960                   Cafelândia
# 3969                 Campo Bonito
# 3978     Capitão Leônidas Marques
# 3981                     Cascavel
# 3983                   Catanduvas
# 3986                     Céu Azul
# 3996                     Corbélia
# 4009              Diamante do Sul
# 4010             Diamante D'Oeste
# 4017          Entre Rios do Oeste
# 4031             Formosa do Oeste
# 4032                Foz do Iguaçu
# 4041                       Guaíra
# 4047                   Guaraniaçu
# 4053                        Ibema
# 4057                       Iguatu
# 4065             Iracema do Oeste
# 4069                 Itaipulândia
# 4090                     Jesuítas
# 4101                    Lindoeste
# 4116      Marechal Cândido Rondon
# 4124                       Maripá
# 4128                   Matelândia
# ...
