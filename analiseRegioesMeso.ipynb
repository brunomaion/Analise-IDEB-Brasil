# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import sys
import joblib

tipodoaquivo = joblib.load('tipodoarquivo.pkl')
display(tipodoaquivo)
# Out:
# '.png'

# %%
dfMeso = pd.read_csv("planilhas/MesoPR.csv", sep=";")
total_linhas = len(dfMeso)
dfMeso.rename(columns={'municipio': 'Região'}, inplace=True)
display(dfMeso)

dfBrasilOeste = pd.read_csv("planilhas/BrasilPrOeste.csv", sep=";")
total_linhas = len(dfBrasilOeste)
display(dfBrasilOeste)
# Out:
#                         Região  TXApro_Total_2017  TXApro_1aSERIE_2017  \
# 0          Noroeste Paranaense             82.507               77.140
# 1  Centro Ocidental Paranaense             81.312               76.086
# 2     Norte Central Paranaense             81.317               73.184
# 3    Norte Pioneiro Paranaense             80.797               74.600
# 4   Centro Oriental Paranaense             81.742               77.119
# 5             Oeste Paranaense             81.847               76.555
# 6          Sudoeste Paranaense             83.848               79.674
# 7        Centro Sul Paranaense             81.952               74.916
# 8           Sudeste Paranaense             83.863               78.781
# 9                Metropolitana             79.458               73.637
#
#    TXApro_2aSERIE_2017  TXApro_3aSERIE_2017  TXApro_4aSERIE_2017  \
# 0               81.252               89.309               97.567
# ...

# %% [markdown]
# # ARPOVAÇÃO TOTAL

# %%
def graficoLinhaAprovTotal(df, titulo, nomeSalvarArquivo):
    # Configurar o gráfico
    plt.figure(figsize=(12, 6))

    # Plotar cada Região
    for index, row in df.iterrows():
        plt.plot(['2017', '2019', '2021', '2023'], 
                [row['TXApro_Total_2017'], row['TXApro_Total_2019'], row['TXApro_Total_2021'], row['TXApro_Total_2023']],
                label=row['Região'])

    # Adicionar títulos e labels
    plt.grid()
    plt.title(titulo)
    plt.xlabel('Ano')
    plt.ylabel('Taxa de Aprovação Total')
    plt.legend(title='Região', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.yticks(range(70, 101, 5))

    # Ajustar o layout
    plt.tight_layout()

    nome = 'graficos/meso/' + 'linha'+ 'AprovTotal' +nomeSalvarArquivo + tipodoaquivo
    plt.savefig(nome, dpi=300, bbox_inches = "tight")
    # Mostrar o gráfico
    plt.show()

# %%
graficoLinhaAprovTotal(dfMeso, 'Mesorregiões do Paraná', 'mesoPR')
graficoLinhaAprovTotal(dfBrasilOeste, 'Região Oeste', 'BraPrOeste')

# %% [markdown]
# # IDEB

# %%
def graficoLinhaIdebTotal(df, titulo, nomeSalvarArquivo):
    # Configurar o gráfico
    plt.figure(figsize=(12, 6))

    # Plotar cada Região
    for index, row in df.iterrows():
        plt.plot(['2017', '2019', '2021', '2023'], 
                [row['IDEB_2017'], row['IDEB_2019'], row['IDEB_2021'], row['IDEB_2023']],
                label=row['Região'])

    # Adicionar títulos e labels
    plt.grid()
    plt.title(titulo)
    plt.xlabel('Ano')
    plt.ylabel('Taxa de Aprovação Total')
    plt.legend(title='Região', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.yticks(np.arange(3, 6, 0.5))

    # Ajustar o layout
    plt.tight_layout()

    nome = 'graficos/meso/' + 'linha' + 'Ideb'+ nomeSalvarArquivo + tipodoaquivo
    plt.savefig(nome, dpi=300, bbox_inches = "tight")
    # Mostrar o gráfico
    plt.show()

# %%
graficoLinhaIdebTotal(dfMeso, 'Mesorregiões do Paraná', 'mesoPR')
graficoLinhaIdebTotal(dfBrasilOeste, 'Região Oeste', 'BraPrOeste')

# %% [markdown]
# # Indicator Rendimento

# %%
def graficoIndicadorRend(df, titulo, nomeSalvarArquivo):
    # Configurar o gráfico
    plt.figure(figsize=(12, 6))

    # Plotar cada Região
    for index, row in df.iterrows():
        plt.plot(['2017', '2019', '2021', '2023'], 
                [row['Indicador de Rendimento (P)_2017'], row['Indicador de Rendimento (P)_2019'], row['Indicador de Rendimento (P)_2021'], row['Indicador de Rendimento (P)_2023']],
                label=row['Região'])

    # Adicionar títulos e labels
    plt.grid()
    plt.title(titulo)
    plt.xlabel('Ano')
    plt.ylabel('Indicador de Rendimento (P)')
    plt.legend(title='Região', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.yticks(np.arange(.7, 1, 0.05))

    # Ajustar o layout
    plt.tight_layout()

    nome = 'graficos/meso/' + 'linha'+ 'IndicadorRendimento' +nomeSalvarArquivo + tipodoaquivo
    plt.savefig(nome, dpi=300, bbox_inches = "tight")
    # Mostrar o gráfico
    plt.show()

# %%
graficoIndicadorRend(dfMeso, 'Mesorregiões do Paraná', 'mesoPR')
graficoIndicadorRend(dfBrasilOeste, 'Região Oeste', 'BraPrOeste')

# %% [markdown]
# # Media Padronizada

# %%
def graficoMediaP(df, titulo, nomeSalvarArquivo):
    # Configurar o gráfico
    plt.figure(figsize=(12, 6))

    # Plotar cada Região
    for index, row in df.iterrows():
        plt.plot(['2017', '2019', '2021', '2023'], 
                [row['saeb_Media_padronizada_2017'], 
                 row['saeb_Media_padronizada_2019'], 
                 row['saeb_Media_padronizada_2021'], 
                 row['saeb_Media_padronizada_2023']],
                label=row['Região'])

    # Adicionar títulos e labels
    plt.grid()
    plt.title(titulo)
    plt.xlabel('Ano')
    plt.ylabel('Média Padronizada')
    plt.legend(title='Região', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.yticks(np.arange(3.5,6,0.5))

    # Ajustar o layout
    plt.tight_layout()

    nome = 'graficos/meso/' + 'linha'+ 'MediaP' +nomeSalvarArquivo + tipodoaquivo
    plt.savefig(nome, dpi=300, bbox_inches = "tight")
    # Mostrar o gráfico
    plt.show()

# %%
graficoMediaP(dfMeso, 'Mesorregiões do Paraná', 'mesoPR')
graficoMediaP(dfBrasilOeste, 'Região Oeste', 'BraPrOeste')

# %% [markdown]
# # Saeb MAT e PORT e MATxPORT

# %% [markdown]
# ### MAT

# %%
def graficoMediaMat(df, titulo, nomeSalvarArquivo):
    # Configurar o gráfico
    plt.figure(figsize=(12, 6))

    # Plotar cada Região
    for index, row in df.iterrows():
        plt.plot(['2017', '2019', '2021', '2023'], 
                [row['saeb_Mat_2017'], 
                 row['saeb_Mat_2019'], 
                 row['saeb_Mat_2021'], 
                 row['saeb_Mat_2023']],
                label=row['Região'])

    # Adicionar títulos e labels
    plt.grid()
    plt.title(titulo)

    plt.xlabel('Ano')
    plt.ylabel('Média Matemática')
    plt.legend(title='Região', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.yticks(np.arange(240,320,10))

    # Ajustar o layout
    plt.tight_layout()

    nome = 'graficos/meso/' + 'linha'+ 'MédiaMatemática' +nomeSalvarArquivo + tipodoaquivo
    plt.savefig(nome, dpi=300, bbox_inches = "tight")
    # Mostrar o gráfico
    plt.show()

# %%
graficoMediaMat(dfMeso, 'Mesorregiões do Paraná', 'mesoPR')
graficoMediaMat(dfBrasilOeste, 'Região Oeste', 'BraPrOeste')

# %% [markdown]
# ### PORT

# %%
def graficoMediaPort(df, titulo, nomeSalvarArquivo):
    # Configurar o gráfico
    plt.figure(figsize=(12, 6))

    # Plotar cada Região
    for index, row in df.iterrows():
        plt.plot(['2017', '2019', '2021', '2023'], 
                [row['saeb_Port_2017'], 
                 row['saeb_Port_2019'], 
                 row['saeb_Port_2021'], 
                 row['saeb_Port_2023']],
                label=row['Região'])

    # Adicionar títulos e labels
    plt.grid()
    plt.title(titulo)
    plt.xlabel('Ano')
    plt.ylabel('Média Matemática')
    plt.legend(title='Região', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.yticks(np.arange(240,320,10))

    # Ajustar o layout
    plt.tight_layout()

    nome = 'graficos/meso/' + 'linha'+ 'MédiaPortugues' +nomeSalvarArquivo + tipodoaquivo
    plt.savefig(nome, dpi=300, bbox_inches = "tight")
    # Mostrar o gráfico
    plt.show()

# %%
graficoMediaPort(dfMeso, 'Mesorregiões do Paraná', 'mesoPR')
graficoMediaPort(dfBrasilOeste, 'Região Oeste', 'BraPrOeste')

# %% [markdown]
# # BARRA

# %%
import matplotlib.pyplot as plt
import numpy as np

def graficoBarra20171(df, titulo, nomeSalvarArquivo, coluna):
  
    # Configurar o gráfico
    plt.figure(figsize=(12, 6))

    # Plotar os dados de 2017 para cada Região
    bars = plt.bar(df['Região'], coluna, color='skyblue')

    # Adicionar títulos e labels
    plt.grid(axis='y')
    plt.title(titulo)
    plt.xlabel('Região')
    plt.ylabel(str(coluna.name))
    plt.xticks(rotation=50)

    # Adicionar os valores no topo das barras
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width() / 2, height, f'{height:.2f}', ha='center', va='bottom')

    # Ajustar o layout
    plt.tight_layout()

    # Salvar o gráfico
    nome = 'graficos/meso/' + 'barra' + str(coluna.name) + nomeSalvarArquivo + '.png'
    plt.savefig(nome, dpi=300, bbox_inches="tight")

    # Mostrar o gráfico
    plt.show()

def graficoBarra20172(df, titulo, nomeSalvarArquivo, coluna):
  
    # Configurar o gráfico
    plt.figure(figsize=(12, 6))

    # Plotar os dados de 2017 para cada Região
    bars = plt.bar(df['Região'], coluna, color='skyblue')

    # Adicionar títulos e labels
    plt.grid(axis='y')
    plt.title(titulo)
    plt.xlabel('Região')
    plt.ylabel(str(coluna.name))
    #plt.xticks(rotation=50)

    # Adicionar os valores no topo das barras
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width() / 2, height, f'{height:.2f}', ha='center', va='bottom')

    # Ajustar o layout
    plt.tight_layout()

    nome = 'graficos/meso/' + 'barra' + 'barra' + str(coluna.name) + nomeSalvarArquivo + '.png'
    plt.savefig(nome, dpi=300, bbox_inches="tight")

    # Mostrar o gráfico
    plt.show()

# %%
graficoBarra20171(dfMeso, 'Mesorregiões do Paraná', 'mesoPR', dfMeso['TXApro_Total_2017'])
graficoBarra20172(dfBrasilOeste, 'Região Oeste', 'BraPrOeste', dfBrasilOeste['TXApro_Total_2017'])

graficoBarra20171(dfMeso, 'Mesorregiões do Paraná', 'mesoPR', dfMeso['Indicador de Rendimento (P)_2017'])
graficoBarra20172(dfBrasilOeste, 'Região Oeste', 'BraPrOeste', dfBrasilOeste['Indicador de Rendimento (P)_2017'])

graficoBarra20171(dfMeso, 'Mesorregiões do Paraná', 'mesoPR', dfMeso['saeb_Media_padronizada_2017'])
graficoBarra20172(dfBrasilOeste, 'Região Oeste', 'BraPrOeste', dfBrasilOeste['saeb_Media_padronizada_2017'])

graficoBarra20171(dfMeso, 'Mesorregiões do Paraná', 'mesoPR', dfMeso['IDEB_2017'])
graficoBarra20172(dfBrasilOeste, 'Região Oeste', 'BraPrOeste', dfBrasilOeste['IDEB_2017'])

graficoBarra20171(dfMeso, 'Mesorregiões do Paraná', 'mesoPR', dfMeso['saeb_Mat_2017'])
graficoBarra20172(dfBrasilOeste, 'Região Oeste', 'BraPrOeste', dfBrasilOeste['saeb_Mat_2017'])

graficoBarra20171(dfMeso, 'Mesorregiões do Paraná', 'mesoPR', dfMeso['saeb_Port_2017'])
graficoBarra20172(dfBrasilOeste, 'Região Oeste', 'BraPrOeste', dfBrasilOeste['saeb_Port_2017'])
